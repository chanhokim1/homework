# %% [markdown]
# ## Boston House price

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
boston = load_boston()

# %%
x = boston.data    # features
y = boston.target  # labels

name = boston.feature_names # name of features

# %%
from sklearn.linear_model import LinearRegression

# %%
regress = LinearRegression()
for i in range(len(name)):
    feature = np.atleast_2d(x[:,i])
    X = np.transpose(feature)
    regress.fit(X,y)
    fea_name = str(name[i])
    print(name[i])
    print('coef', regress.coef_)
    print('intercept', regress.intercept_)
    print('score', regress.score(X,y))
    plt.plot(X, regress.predict(X))
    plt.plot(X,y,'o')
    plt.title(fea_name)
    plt.show()
# Out:
# CRIM
# coef [-0.41519028]
# intercept 24.03310617412388
# score 0.15078046904975717
# ZN
# coef [0.14213999]
# intercept 20.917579117799832
# score 0.12992084489428946
# INDUS
# coef [-0.64849005]
# intercept 29.75489651192849
# score 0.2339900304444752
# CHAS
# coef [6.34615711]
# intercept 22.093842887473464
# score 0.03071612970877491
# NOX
# coef [-33.91605501]
# intercept 41.345874467973246
# score 0.182603042501699
# RM
# coef [9.10210898]
# intercept -34.670620776438554
# score 0.48352545599133423
# AGE
# coef [-0.12316272]
# intercept 30.97867776261804
# score 0.14209474407780442
# DIS
# coef [1.09161302]
# intercept 18.390088330493388
# score 0.062464372121782574
# RAD
# coef [-0.4030954]
# intercept 26.382128362272397
# score 0.14563857991232532
# TAX
# coef [-0.0255681]
# intercept 32.9706544936663
# score 0.2195259210442192
# PTRATIO
# coef [-2.1571753]
# intercept 62.34462747483266
# score 0.257847318009223
# B
# coef [0.03359306]
# intercept 10.551034138417155
# ...

# %% [markdown]
# 각각의 features로 coef와 intercept로 regression을 한 결과 RM, LSTAT 적합도(score)가 가장 높다.
#
# Lasso regression를 적용하면 결과는 다음과 같다.

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=10)
for i in range(len(name)):
    feature = np.atleast_2d(x[:,i])
    Xl = np.transpose(feature)
    lasso.fit(Xl,y)
    fea_name = str(name[i])
    print(name[i])
    print('coef',lasso.coef_)
    print('intercept',lasso.intercept_)
    print('score', lasso.score(Xl,y))
    print('')
    plt.plot(Xl,lasso.predict(Xl))
    plt.plot(Xl,y,'o')
    plt.title(fea_name)
    plt.show()
# Out:
# CRIM
# coef [-0.27976299]
# intercept 23.54373646171968
# score 0.13473829839086016
# ZN
# coef [0.1237191]
# intercept 21.126907450199322
# score 0.12773878020573803
# INDUS
# coef [-0.43559468]
# intercept 27.383927878993298
# score 0.20877130370398544
# CHAS
# coef [0.]
# intercept 22.532806324110677
# score 0.0
# NOX
# coef [-0.]
# intercept 22.532806324110677
# score 0.0
# RM
# coef [0.]
# intercept 22.532806324110677
# score 0.0
# AGE
# coef [-0.11051718]
# intercept 30.1115109199501
# score 0.1405968041100114
# DIS
# coef [0.]
# intercept 22.532806324110677
# score 0.0
# RAD
# coef [-0.27093657]
# intercept 25.120089921436435
# score 0.1299835785346396
# TAX
# coef [-0.02521535]
# intercept 32.82664850596361
# score 0.2194841356063092
# PTRATIO
# coef [-0.01938455]
# intercept 22.890558493866983
# score 0.004613251664220663
# B
# coef [0.03239089]
# intercept 10.979817509005787
# score 0.11105371385610663
# LSTAT
# coef [-0.75356246]
# intercept 32.06767976518519
# ...

# %% [markdown]
# Ridge regression을 적용하면 다음과 같다.

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=10)
for i in range(len(name)):
    feature = np.atleast_2d(x[:,i])
    Xr = np.transpose(feature)
    ridge.fit(Xr,y)
    fea_name = str(name[i])
    print(name[i])
    print(ridge.coef_)
    print(ridge.intercept_)
    print(ridge.score(Xr,y))
    print('')
    plt.plot(Xr,ridge.predict(Xr))
    plt.plot(Xr,y,'o')
    plt.title(fea_name)
    plt.show()
# Out:
# CRIM
# [-0.41507918]
# 24.03270473700658
# 0.1507804582547232
# ZN
# [0.14213482]
# 20.917637917888356
# 0.12992084472211562
# INDUS
# [-0.64821732]
# 29.751859154346427
# 0.23398998905752855
# CHAS
# [4.85571594]
# 22.196936644233006
# 0.029021891274144784
# NOX
# [-13.70501642]
# 30.134911217932377
# 0.11775832387375695
# RM
# [8.75108791]
# -32.464581695891056
# 0.4828063355237232
# AGE
# [-0.12315964]
# 30.978466695505297
# 0.1420947439890624
# DIS
# [1.08675963]
# 18.40850714238213
# 0.062463137355213805
# RAD
# [-0.40299014]
# 26.381123245573846
# 0.1456385699825158
# TAX
# [-0.02556808]
# 32.97064721707174
# 0.2195259210441125
# PTRATIO
# [-2.14809983]
# 62.17713482916767
# 0.25784275417337943
# B
# [0.03359298]
# 10.551062605040324
# 0.11119611824573494
# LSTAT
# [-0.94968058]
# 34.549174755020275
# 0.5441462155995531

# %% [markdown]
# coef와 intercept는 변하지만 score는 3가지 regression에서 거의 일정하다.

# %% [markdown]
# ## Diabets

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
dia = load_diabetes()
dia
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
x = dia.data
y = dia.target

name = dia.feature_names

# %% [markdown]
# linear regression을 적용하면

# %%
from sklearn.linear_model import LinearRegression
regress = LinearRegression()
for i in range(len(name)):
    feature = np.atleast_2d(x[:,i])
    X = np.transpose(feature)
    regress.fit(X,y)
    fea_name = str(name[i])
    print(name[i])
    print('coef', regress.coef_)
    print('intercept', regress.intercept_)
    print('score', regress.score(X,y))
    plt.figure(figsize=(16,9))
    plt.plot(X,regress.predict(X))
    plt.plot(X,y,'o')
    plt.title(fea_name)
    plt.show()
# Out:
# age
# coef [304.18307453]
# intercept 152.13348416289605
# score 0.03530218264671636
# sex
# coef [69.71535568]
# intercept 152.13348416289594
# score 0.0018543357106460823
# bmi
# coef [949.43526038]
# intercept 152.1334841628967
# score 0.3439237602253803
# bp
# coef [714.7416437]
# intercept 152.13348416289585
# score 0.19490798886682947
# s1
# coef [343.25445189]
# intercept 152.13348416289597
# score 0.04495353245556555
# s2
# coef [281.78459335]
# intercept 152.1334841628959
# score 0.030294651136685613
# s3
# coef [-639.14527932]
# intercept 152.13348416289566
# score 0.1558585524453051
# s4
# coef [696.88303009]
# intercept 152.13348416289568
# score 0.18528968598509699
# s5
# coef [916.13872282]
# intercept 152.13348416289628
# score 0.32022405096453443
# s6
# coef [619.22282068]
# intercept 152.13348416289614
# score 0.1462936157229343

# %% [markdown]
# linear regression을 적용하면 성별(sex)에 무관하게 진행률이 비슷하고 나이가 많을수록,BMI 수치와 혈압이 높을수록 진행이 빠르다.
